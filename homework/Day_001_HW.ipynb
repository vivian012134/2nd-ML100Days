# %% [markdown]
# ## 作業1
#
# <font color=gray> 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下： </font>
# ##### 選擇競賽：[LANL Earthquake Prediction](https://www.kaggle.com/c/LANL-Earthquake-Prediction/data)
# 1. <font color=gray> 你選的這組資料為何重要 </font>
# > 若能預測地震何時發生，則可增加人們逃生的時間及減少天然災害造成的影響。
# 2. <font color=gray> 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集) </font>
# > 資料來自於：Los Alamos National Laboratory，由此國家實驗室進行實驗得來的數據。
# 3. <font color=gray> 蒐集而來的資料型態為何 </font>
# > 結構化表格，紀錄實驗中單一、連續的訓練間隔。
# 4. <font color=gray> 這組資料想解決的問題如何評估 </font>
# > 利用MSE(mean absolute error)進行評估。

# %% [markdown]
# ## 作業2
#
# <font color=gray> 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案： </font>
# 1. <font color=gray> 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」) </font>
# > 以「載客數」作為業績指標，假設能判斷何時何地會有較多人，即可通知司機事先到附近方便人們叫車。
# 2. <font color=gray> 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集) </font>
# > 需要有拍攝人行道、馬路的攝影機(包含：道路監視器、民眾手機相機等)。
# 3. <font color=gray> 蒐集而來的資料型態為何 </font>
# > 資料搜集型態為圖片檔，並紀錄所在位置經緯度。
# 4. <font color=gray> 你要回答的問題，其如何評估 (tips：你的假設如何驗證) </font>
# > 辨識圖片中的人數，利用準確率進行驗證。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    mse = sum((y - yp)**2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 249.356
# The Mean absolute error is 12.475
